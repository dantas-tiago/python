# %% [markdown]
# # <font color='Green'>Funções - Python </font>

# %% [markdown]
# As funções em Python (que são declaradas pela palavra reservada def) desempenham um papel fundamental na programação e oferecem inúmeras vantagens. Aqui estão algumas das principais razões pelas quais as funções são importantes em Python:
#
# - Modularidade: Funções permitem dividir um programa em partes menores e mais gerenciáveis. Isso facilita a compreensão do código, a depuração e a manutenção, tornando o código mais organizado e legível.
#
# - Reutilização de código: Uma vez que você definiu uma função, pode chamá-la sempre que precisar executar uma tarefa específica, em vez de repetir o mesmo código em vários lugares. Isso economiza tempo e esforço, além de manter o código DRY (Don't Repeat Yourself).
#
# - Abstração: Funções permitem abstrair detalhes complexos e fornecer uma interface simples para realizar uma tarefa. Isso torna o código mais fácil de usar e entender para outros programadores.
#
# - Encapsulamento: Funções podem encapsular funcionalidades específicas e esconder os detalhes de implementação. Isso ajuda a proteger o código interno e a fornecer uma API limpa para o uso externo.
#
# - Legibilidade: Dividir o código em funções com nomes descritivos ajuda a tornar o código mais legível. Você pode criar funções com nomes que descrevem claramente a finalidade da função, o que melhora a documentação embutida no código.
#
# - Testabilidade: Funções facilitam a criação de testes unitários para partes específicas do código. Isso é fundamental para garantir que seu código funcione corretamente e para detectar problemas rapidamente.
#
# Sintaxe:
# def nome_funcao(parâmetro1, parâmetro2,....):
#      "o que deve ser executado"

# %%
# exemplo de função sem parâmetro
def funcao():
    print("Entrei na funcao sem parametros")
print(funcao())
# Out:
# Entrei na funcao sem parametros
# None

# %%
#tentando passar uma argumento para uma função sem parametro
funcao(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\RTIRVR\OneDrive\Cursos\Programação python\Github-dantas\4-funcoes\4Funcoes.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/RTIRVR/OneDrive/Cursos/Programa%C3%A7%C3%A3o%20python/Github-dantas/4-funcoes/4Funcoes.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> #tentando passar uma argumento para uma função sem parametro
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RTIRVR/OneDrive/Cursos/Programa%C3%A7%C3%A3o%20python/Github-dantas/4-funcoes/4Funcoes.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> funcao(2)
#
# TypeError: funcao() takes 0 positional arguments but 1 was given

# %%
# exemplo de função sem parâmetro na entrada, mas retornando 1 valor None
def funcao():
    print("Entrei na funcao sem parametros")
print("Imprimindo o valor retornado pela funcao", funcao()) # none é retornado por padrão
# Out:
# Entrei na funcao sem parametros
# Imprimindo o valor retornado pela funcao None

# %%
# exemplo de função sem parâmetro na entrada, mas retornando 1 valor None (mesmo resultado se coloca o return ou não)
def funcao():
    print("Entrei na funcao sem parametros")
    return None
print("Imprimindo o valor retornado pela funcao", funcao()) # none é retornado por padrão
# Out:
# Entrei na funcao sem parametros
# Imprimindo o valor retornado pela funcao None

# %%
# exemplo de função sem parâmetro na entrada, mas retornando 1 valor (pode retornar mais de um valor ao mesmo tempo)
def funcao():
    print("Entrei na funcao sem parametros")
    return 2
print("Imprimindo o valor retornado pela funcao", funcao())
# Out:
# Entrei na funcao sem parametros
# Imprimindo o valor retornado pela funcao 2

# %%
# exemplo de função sem parâmetro na entrada, mas retornando 2 valores
def funcao():
    print("Entrei na funcao sem parametros")
    valor1 = 10
    valor2 = 20
    return valor1, valor2 # retorna em formato de tupla
print("Imprimindo o valor retornado pela funcao", funcao())
# Out:
# Entrei na funcao sem parametros
# Imprimindo o valor retornado pela funcao (10, 20)

# %%
def funcao():
    listar_objetos = ['python','numpy']
    print(listar_objetos)
    listar_objetos.insert(10,'NPL') # insere na posição 10 o valor NPL
    #print(listar_objetos[:3])
    return listar_objetos

print(funcao())
# Out:
# ['python', 'numpy']
# ['python', 'numpy', 'NPL']

# %% [markdown]
# ### Funções com parâmetro numéricos

# %%
# exemplo de função de ao quadrado (valor numérico)
def ao_quadrado(num):
    return num**2
print(ao_quadrado(4))
# Out:
# 16

# %%
#tentando passar mais de um argumento para uma função que espera um só arg
print(ao_quadrado(4, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\RTIRVR\OneDrive\Cursos\Programação python\Github-dantas\4-funcoes\4Funcoes.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/RTIRVR/OneDrive/Cursos/Programa%C3%A7%C3%A3o%20python/Github-dantas/4-funcoes/4Funcoes.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> #tentando passar mais de um argumento para uma função que espera um só arg
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RTIRVR/OneDrive/Cursos/Programa%C3%A7%C3%A3o%20python/Github-dantas/4-funcoes/4Funcoes.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> print(ao_quadrado(4, 5))
#
# TypeError: ao_quadrado() takes 1 positional argument but 2 were given

# %%
# Usando 2 returns
def verifica_valor_par(num):
    if num % 2 == 0:
        return True
    else:
        return False

print(verifica_valor_par(2))
print(verifica_valor_par(3))
# Out:
# True
# False

# %%
# somar elementos de uma lista
def somando_listas(lista):
    soma = 0
    for i in lista:
        soma = soma +i
    return soma

lista1 = [10,20,30,40,50]
somando_listas(lista1)
# Out:
# 150

# %%
# Função com dois parâmetros numéricos e somar estes números sem return
def soma(primeiro_numero, segundo_numero): # espera parâmentro para duas variáveis locais
    print("Primeiro número: " , primeiro_numero)
    print("Segundo número: " , segundo_numero)
    print("Soma: ", primeiro_numero + segundo_numero)

# %%
# chamando a função e somando os números
soma(4,5) # aqui ao chamar a função, estamos passando argumentos
# Out:
# Primeiro número:  4
# Segundo número:  5
# Soma:  9

# %%
#chamando a mesma função com variáveis externas (globais)
pri_num = 4
seg_num = 5

# Função com dois parâmetros numéricos e  variaveis globais (não é uma boa prática)
def soma_global():
    global pri_num,seg_num
    print("Primeiro número: " , pri_num)
    print("Segundo número: " , seg_num)
    print("Soma: ", pri_num + seg_num)

soma_global()
# Out:
# Primeiro número:  4
# Segundo número:  5
# Soma:  9

# %%
#diferenciando variáveis locais e globais

print(pri_num) #variável global
# Out:
# 4

# %%
#diferenciando variáveis locais e globais

print(primeiro_numero) #variável local, só existe dentro do contexto da função

# quando é necessário retornar o valor, deve-se usar o return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 #diferenciando variáveis locais e globais
# ----> 3 print(primeiro_numero) #variável local, só existe dentro do contexto da função
#       5 # quando é necessário retornar o valor, deve-se usar o return
#
# NameError: name 'primeiro_numero' is not defined

# %%
# Função com dois parâmetros numéricos e retornar esta soma
def soma(primeiro_numero, segundo_numero):
    print("Entrei na função")
    print("Primeiro número: " , primeiro_numero)
    print("Segundo número: " , segundo_numero)
    print("Soma: ", primeiro_numero + segundo_numero)
    print("Saindo da função")
    return primeiro_numero + segundo_numero

# %%
pri_num = 4
seg_num = 5

# Função de soma que retorna os dois valores somados
def soma_dois(primeiro_numero, segundo_numero):
    soma =  primeiro_numero + segundo_numero
    return soma,  primeiro_numero , segundo_numero

retorno_soma, retorno_primeiro_num, retorno_segundo_num = soma_dois(pri_num,seg_num)

print(f"soma numero {retorno_soma}, primeiro numero retornado {retorno_primeiro_num}, segundo numero retornado {retorno_segundo_num}")
# Out:
# soma numero 9, primeiro numero retornado 4, segundo numero retornado 5

# %%
#diferenciando variáveis locais e globais

var_retornado = soma(pri_num, seg_num)

print("Resultado retornado da função soma: " + str(var_retornado))
print(str(var_retornado), "está dentro de uma variável global " )
# Out:
# Entrei na função
# Primeiro número:  4
# Segundo número:  5
# Soma:  9
# Saindo da função
# Resultado retornado da função soma: 9
# 9 está dentro de uma variável global

# %%
# Definir um parametro default antes de um parametro não definido
# gerara um erro, se precisar  a forma correta é colocar o valor definido depois
def minha_funcao(a=0, b):
    sum = a + b
    return sum
print(my_funcao(a=5,b=10))
# Out:
#   Cell In[9], line 3
#     def minha_funcao(a=0, b):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
# forma correta é coloca o parametro definido depois
def my_funcao(b, a=0):
    sum = a + b
    return sum
# print(my_funcao(a=5,b=10))
print(my_funcao(5,10))
# Out:
# 15

# %%
def my_funcao(b, a=0):
    sum = a + b
    return sum
print(my_funcao(b=10))
# Out:
# 10

# %%
# outro exemplo, ctrl d seleciona todos
def calculadora(v1=0, v2, operacao="+"):
    if operacao == "+":
        return v1 + v2
    elif operacao == "-":
        return v1 - v2
    elif operacao == "*":
        return v1 * v2
    elif operacao == "/":
        return v1 / v2
# Out:
#   Cell In[6], line 2
#     def calculadora(v1=0, v2, operacao="+"):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
# outro exemplo, ctrl d seleciona todos
def calculadora( v2, v1=0, operacao="+"):
    if operacao == "+":
        return v1 + v2
    elif operacao == "-":
        return v1 - v2
    elif operacao == "*":
        return v1 * v2
    elif operacao == "/":
        return v1 / v2
    

calculadora(10, 0, "+")
# Out:
# 10

# %% [markdown]
# ### Funções com parâmetros de texto

# %%
# exemplo de função passando parâmetro de texto
def texto(str):
    print("meu nome é", str)

texto("Tiago")
# Out:
# meu nome é Tiago

# %%
# exemplo de função passando parâmetro de texto
def texto(str):
    print("meu nome é", str)

texto("Tiago")
texto() # se a função exige um parâmetro e vc não passa o valor, é gerado um erro
# Out:
# meu nome é Tiago
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3     print("meu nome é", str)
#       5 texto("Tiago")
# ----> 6 texto() # se a função exige um parâmetro e vc não passa o valor, é gerado um erro
#
# TypeError: texto() missing 1 required positional argument: 'str'

# %%
# exemplo de função passando parâmetro de texto, já definido
def texto(str='Tiago'):
    print("meu nome é", str)

texto()
texto("Tiago")
# Out:
# meu nome é Tiago
# meu nome é Tiago

# %%
# Definindo uma função com parâmetro
def texto_com_placeholder(str):
    print('meu nome é %s' %(str)) #placeholder %s, é um estilo antigo de interpolação de variáveis, é recomendado o uso de f-string

texto_com_placeholder("Tiago")

#%d int
# %.4f float ou double com quatro casas decimais
# %b boolean
# %c caractere (char)
#%s string
# \n pular linha
# Out:
# meu nome é Tiago

# %%
# Usando método split para criar uma função que separa as palavras 
def separa_palavras(texto_recebido):
    return texto_recebido.split() 

# por padrão a função split considera o espaço com separador

# %%
var_texto = "Criando um texto que será dividido a cada espaço!"
separa_palavras(var_texto)
# Out:
# ['Criando', 'um', 'texto', 'que', 'será', 'dividido', 'a', 'cada', 'espaço!']

# %% [markdown]
# ### Função para receber quantidade indefinida de argumentos

# %%
# para quando queremos utilizar uma função com qtdade
# de parametros indefinidos, usamos um * (referente a uma tupla)
def funcao_com_qtdade_parametro_indefinidos(*parametros):
    for i in parametros:
        print(i)

# %%
funcao_com_qtdade_parametro_indefinidos(1, 2, 3, "nome")
# Out:
# 1
# 2
# 3
# nome

# %%
funcao_com_qtdade_parametro_indefinidos(0, 3, 6, 9, 12)
# Out:
# 0
# 3
# 6
# 9
# 12

# %%
funcao_com_qtdade_parametro_indefinidos([0, 3], [6, 9, 12])
# Out:
# [0, 3]
# [6, 9, 12]

# %%
# para quando queremos utilizar uma função com qtdade 
# de parametros indefinidos e parâmetros nomeados, 
# usamos dois **. Usando quando vamos passar um dicionário
def funcao_com_parametro_nomeados_indefinidos(**kwargs): #kwargs = Keyword Arguments, dict
    for i in kwargs:
        print(i)

# %%
#chamando função com parâmetros nomeados kwargs
funcao_com_parametro_nomeados_indefinidos(a = 2, b = 3)
# Out:
# a
# b

# %%
# para quando queremos utilizar uma função com qtdade 
# de parametros indefinidos e parâmetros nomeados, 
# usamos dois **
def funcao_com_parametro_nomeados_indefinidos(**kwargs): #kwargs = Keyword Arguments, dict
    print(kwargs)

# %%
#chamando função com parâmetros nomeados kwargs
funcao_com_parametro_nomeados_indefinidos(a = 2, b = 3)
# Out:
# {'a': 2, 'b': 3}

# %%
# misturandos config para os parametros v1
def funcao_com_varios_tipos_parametros(a, b,*args, **kwargs): #kwargs deve ser sempre o último
    return a,b, args, kwargs

# %%
funcao_com_varios_tipos_parametros(1,2,'azul', 'amarelos', 5 , chave1 =3, chave2='teste')
# a = 1
# b = 2
# *arg = 'azul', 'amarelos', 5
# **kwargs = chave1 =3, chave2='teste'
# Out:
# (1, 2, ('azul', 'amarelos', 5), {'chave1': 3, 'chave2': 'teste'})

# %%
# misturandos config para os parametros v2
def funcao_com_varios_tipos_parametros(a,*args, b, **kwargs): #kwargs deve ser sempre o último
    return a,args, b,  kwargs

# %%
funcao_com_varios_tipos_parametros(1, 2,'azul', 'amarelos', b=5 , chave1 =3, chave2='teste')
# Out:
# (1, (2, 'azul', 'amarelos'), 5, {'chave1': 3, 'chave2': 'teste'})

# %%
# misturandos config para os parametros v3
def funcao_com_varios_tipos_parametros(*args, a, b, **kwargs): #kwargs deve ser sempre o último
    return args, a, b, kwargs

# %%
funcao_com_varios_tipos_parametros(1, 2,'azul', a = 'amarelos', b= 5 , chave1 =3, chave2='teste')
# Out:
# ((1, 2, 'azul'), 'amarelos', 5, {'chave1': 3, 'chave2': 'teste'})

# %%
# misturandos config para os parametros v4
def funcao_com_varios_tipos_parametros(*args, a, **kwargs, b): #kwargs deve ser sempre o último
    return args, a,kwargs, b
# Out:
#   Cell In[87], line 2
#     def funcao_com_varios_tipos_parametros(*args, a, **kwargs, b): #kwargs deve ser sempre o último
#                                                                ^
# SyntaxError: arguments cannot follow var-keyword argument

# %%
# Forma correta de definição de função com argumento keyword-only
def mostra_dados(primeiro_nome, ultimo_nome, *, idade=None, cidade=None):
    print(f"Name: {primeiro_nome} {ultimo_nome}")
    if idade:
        print(f"Idade: {idade}")
    if cidade:
        print(f"cidade: {cidade}")

# Chamando a função
mostra_dados("Tiago", "Dantas", idade=30, cidade="Rio Verde")
# Out:
# Name: Tiago Dantas
# Idade: 30
# cidade: Rio Verde

# %% [markdown]
# #### Para mais conteúdos - <a href="https://www.youtube.com/channel/UCsqbB1Hg-qVNb96r86S0mZA">Youtube</a>
